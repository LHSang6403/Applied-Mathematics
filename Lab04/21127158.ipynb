# %% [markdown]
# Applied math
# Project 1: Color Compression
# Student: Le Hoang Sang
# Class: 21CLC02

# %%
import PIL.Image
import matplotlib.pyplot as plt
import numpy as np

# %%
def read_image(image_path):
    # Read the image using PIL.Image.open()
    image = PIL.Image.open(image_path)
    
    return image

# %%
def display_image(image):
    # Display the image using matplotlib.pyplot.imshow()
    plt.imshow(image)
    plt.axis('off')
    plt.show()

# %%
def main():
    # Specify the path to the image file
    image_path = '/Users/lehoangsang/Downloads/IMG_8324.JPG'

    # Read the image
    image = read_image(image_path)

    # Display the image
    display_image(image)

# Call the main function
if __name__ == '__main__':
    main()
